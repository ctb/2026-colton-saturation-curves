# %%
import polars as pl
import matplotlib.pyplot as plt

# %%
df = pl.read_csv('xxx.csv')

# %%
df
# Out:
# shape: (177, 9)
# ┌─────────┬──────────────┬─────────────┬──────────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ n       ┆ intersect_bp ┆ weighted_bp ┆ sat      ┆ … ┆ f2       ┆ f3       ┆ f4       ┆ f5       │
# │ ---     ┆ ---          ┆ ---         ┆ ---      ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ i64     ┆ i64          ┆ i64         ┆ f64      ┆   ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞═════════╪══════════════╪═════════════╪══════════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ 9887    ┆ 98040000     ┆ 98870000    ┆ 0.008466 ┆ … ┆ 0.008466 ┆ 0.0      ┆ 0.0      ┆ 0.0      │
# │ 19799   ┆ 194980000    ┆ 197990000   ┆ 0.015335 ┆ … ┆ 0.015232 ┆ 0.000103 ┆ 0.0      ┆ 0.0      │
# │ 29706   ┆ 290410000    ┆ 297060000   ┆ 0.022589 ┆ … ┆ 0.022279 ┆ 0.00031  ┆ 0.0      ┆ 0.0      │
# │ 39606   ┆ 383830000    ┆ 396060000   ┆ 0.030977 ┆ … ┆ 0.030091 ┆ 0.000886 ┆ 0.0      ┆ 0.0      │
# │ 49505   ┆ 475670000    ┆ 495050000   ┆ 0.039355 ┆ … ┆ 0.03801  ┆ 0.001303 ┆ 0.000042 ┆ 0.0      │
# │ …       ┆ …            ┆ …           ┆ …        ┆ … ┆ …        ┆ …        ┆ …        ┆ …        │
# │ 1678418 ┆ 2782040000   ┆ 16784180000 ┆ 0.418193 ┆ … ┆ 0.153675 ┆ 0.071164 ┆ 0.042253 ┆ 0.027437 │
# │ 1687993 ┆ 2782040000   ┆ 16879930000 ┆ 0.418193 ┆ … ┆ 0.153675 ┆ 0.071164 ┆ 0.042253 ┆ 0.027437 │
# │ 1697265 ┆ 2782040000   ┆ 16972650000 ┆ 0.418193 ┆ … ┆ 0.153675 ┆ 0.071164 ┆ 0.042253 ┆ 0.027437 │
# │ 1702131 ┆ 2782040000   ┆ 17021310000 ┆ 0.418193 ┆ … ┆ 0.153675 ┆ 0.071164 ┆ 0.042253 ┆ 0.027437 │
# │ 1711870 ┆ 2782040000   ┆ 17118700000 ┆ 0.418193 ┆ … ┆ 0.153675 ┆ 0.071164 ┆ 0.042253 ┆ 0.027437 │
# └─────────┴──────────────┴─────────────┴──────────┴───┴──────────┴──────────┴──────────┴──────────┘

# %%
plt.plot(df['weighted_bp'], df['intersect_bp'])
plt.title('k-mer collector\'s curve')
plt.xlabel('weighted bp')
plt.ylabel('intersect bp')
# Out:
# Text(0, 0.5, 'intersect bp')

# %%
plt.plot(df['weighted_bp'], df['sat'])
plt.title('saturation')
plt.xlabel('weighted bp')
plt.ylabel('saturation')
# Out:
# Text(0, 0.5, 'saturation')

# %%
plt.plot(df['weighted_bp'], df['f1'])
plt.plot(df['weighted_bp'], df['f2'])
plt.plot(df['weighted_bp'], df['f3'])
plt.plot(df['weighted_bp'], df['f4'])
plt.plot(df['weighted_bp'], df['f5'])
plt.xlabel('weighted bp')
# Out:
# Text(0.5, 0, 'weighted bp')
