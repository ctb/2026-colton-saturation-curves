# %%
import polars as pl
import matplotlib.pyplot as plt

# %%
df = pl.read_csv('xxx.csv')

# %%
df
# Out:
# shape: (205, 4)
# ┌─────────┬──────────────┬─────────────┬────────────┐
# │ n       ┆ intersect_bp ┆ weighted_bp ┆ saturation │
# │ ---     ┆ ---          ┆ ---         ┆ ---        │
# │ i64     ┆ i64          ┆ i64         ┆ f64        │
# ╞═════════╪══════════════╪═════════════╪════════════╡
# │ 9890    ┆ 98190000     ┆ 98900000    ┆ 0.007231   │
# │ 19591   ┆ 193100000    ┆ 195910000   ┆ 0.014448   │
# │ 29083   ┆ 284340000    ┆ 290830000   ┆ 0.022332   │
# │ 38449   ┆ 373240000    ┆ 384490000   ┆ 0.029257   │
# │ 47588   ┆ 458530000    ┆ 475880000   ┆ 0.036312   │
# │ …       ┆ …            ┆ …           ┆ …          │
# │ 1679712 ┆ 2782040000   ┆ 16797120000 ┆ 0.418193   │
# │ 1689133 ┆ 2782040000   ┆ 16891330000 ┆ 0.418193   │
# │ 1697742 ┆ 2782040000   ┆ 16977420000 ┆ 0.418193   │
# │ 1703243 ┆ 2782040000   ┆ 17032430000 ┆ 0.418193   │
# │ 1711870 ┆ 2782040000   ┆ 17118700000 ┆ 0.418193   │
# └─────────┴──────────────┴─────────────┴────────────┘

# %%
plt.plot(df['weighted_bp'], df['intersect_bp'])
plt.title('k-mer collector\'s curve')
plt.xlabel('weighted bp')
plt.ylabel('intersect bp')
# Out:
# Text(0, 0.5, 'intersect bp')

# %%
plt.plot(df['weighted_bp'], df['saturation'])
plt.title('saturation')
plt.xlabel('weighted bp')
plt.ylabel('saturation')
# Out:
# Text(0, 0.5, 'saturation')
